# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# - load and select the data(1%-10%)
# - process the data(60%-80%)
# - visualise the data(~%)

# %%
pd.set_option('display.max_columns', None) #optional h ye

# %%
pd.read_excel('Canada.xlsx')
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...

# %%
pd.read_excel('Canada.xlsx', sheet_name=1, skiprows=20) #skip files kiya h kyunki banner h
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2004    2005  \
# 0      Southern Asia  902  Developing regions      16  ...    2978    3436
# ...

# %%
canada = pd.read_excel('Canada.xlsx', sheet_name=1, skiprows=20, skipfooter=2) #last k do rows hatane k liye

# %% [markdown]
# - dataframe -> 2D matrix jismei rows and columns exist karenge
# - series -> 1D matrix with 1 Column

# %% [markdown]
# ###Selection of data
# - head() - top 5
# - tail() - last 5
# - sample() - random

# %%
canada
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %% [markdown]
# #kabhi print na kriyega aur loop mat use krna h pandas mei

# %%
canada #ab kam columns dikha rha
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %%
canada.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  1981  1982  1983  1984  \
# 0    Southern Asia  902  Developing regions    16    39    39    47    71
# 1  Southern Europe  901   Developed regions     1     0     0     0     0
# 2  Northern Africa  902  Developing regions    80    67    71    69    63
# 3        Polynesia  902  Developing regions     0     1     0     0     0
# 4  Southern Europe  901   Developed regions     0     0     0     0     0
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# ...

# %%
canada.head(3)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
# 2  Immigrants  Foreigners      Algeria   903   Africa   912  Northern Africa
#
#    DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 0  902  Developing regions    16    39    39    47    71   340   496   741
# 1  901   Developed regions     1     0     0     0     0     0     1     2
# 2  902  Developing regions    80    67    71    69    63    44    69   132
#
#    1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0   828  1076  1028  1378  1170   713   858  1537  2212  2555  1999  2395
# 1     2     3     3    21    56    96    71    63   113   307   574  1264
# 2   242   434   491   872   795   717   595  1106  2054  1842  2292  2389
#
# ...

# %%
canada.tail(6)
# Out:
#            Type    Coverage                              OdName  AREA  \
# 189  Immigrants  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Immigrants  Foreigners                            Viet Nam   935
# 191  Immigrants  Foreigners                      Western Sahara   903
# 192  Immigrants  Foreigners                               Yemen   935
# 193  Immigrants  Foreigners                              Zambia   903
# 194  Immigrants  Foreigners                            Zimbabwe   903
#
#                             AreaName  REG             RegName  DEV  \
# 189  Latin America and the Caribbean  931       South America  902
# 190                             Asia  920  South-Eastern Asia  902
# 191                           Africa  912     Northern Africa  902
# 192                             Asia  922        Western Asia  902
# 193                           Africa  910      Eastern Africa  902
# 194                           Africa  910      Eastern Africa  902
#
# ...

# %%
canada.sample()
# Out:
#           Type    Coverage        OdName  AREA AreaName  REG         RegName  \
# 27  Immigrants  Foreigners  Burkina Faso   903   Africa  914  Western Africa
#
#     DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 27  902  Developing regions     2     1     3     2     3     2     7    18
#
#     1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 27     6     4     4    22    21    19     3    12    16    23    14    20
#
#     2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 27    31    46    37    34    97    91   147   136   139   162   186   144
#
#     2012  2013
# 27   269   322

# %% [markdown]
# - single column -> series milegi
#     - dict style
#     - object
# - multiple columns
#     - list style

# %%
canada['AreaName'] #string bydefault ismei nhi hota
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
canada[2010]
# Out:
# 0      1758
# 1       561
# 2      4752
# 3         0
# 4         0
#        ...
# 190    1942
# 191       0
# 192     211
# 193     102
# 194     494
# Name: 2010, Length: 195, dtype: int64

# %%
canada.OdName #agar column k naam mei space hoga to ye nhi chalega
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
canada['OdName']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
cols = ['OdName',1980,1990,2000,2010]
canada[cols] #list of columns -> returns dataframe
# Out:
#              OdName  1980  1990  2000  2010
# 0       Afghanistan    16  1028  3326  1758
# 1           Albania     1     3  1816   561
# 2           Algeria    80   491  2867  4752
# 3    American Samoa     0     2     0     0
# 4           Andorra     0     3     0     0
# ..              ...   ...   ...   ...   ...
# 190        Viet Nam  1191  3801  1803  1942
# 191  Western Sahara     0     0     0     0
# 192           Yemen     1     4   122   211
# 193          Zambia    11    77    39   102
# 194        Zimbabwe    72   129    98   494
#
# [195 rows x 5 columns]

# %% [markdown]
# ROW WISE SLICING
# - iloc[] - indexed location
# - loc[] - labelled location #sqare bracktes not () because these are attributes(properties) not functions

# %%
canada.iloc[100]
# Out:
# Type               Immigrants
# Coverage           Foreigners
# OdName          Liechtenstein
# AREA                      908
# AreaName               Europe
# REG                       926
# RegName        Western Europe
# DEV                       901
# DevName     Developed regions
# 1980                        1
# 1981                        4
# 1982                        2
# 1983                        0
# 1984                        0
# 1985                        3
# 1986                        0
# 1987                        1
# 1988                        1
# 1989                        1
# 1990                        0
# 1991                        1
# 1992                        2
# 1993                        3
# 1994                        1
# 1995                        0
# 1996                        7
# 1997                        2
# 1998                        0
# 1999                        2
# 2000                        0
# 2001                        2
# ...

# %%
canada.iloc[66]
# Out:
# Type                Immigrants
# Coverage            Foreigners
# OdName                 Georgia
# AREA                       935
# AreaName                  Asia
# REG                        922
# RegName           Western Asia
# DEV                        902
# DevName     Developing regions
# 1980                         0
# 1981                         0
# 1982                         0
# 1983                         0
# 1984                         0
# 1985                         0
# 1986                         0
# 1987                         0
# 1988                         0
# 1989                         0
# 1990                         0
# 1991                         0
# 1992                         8
# 1993                        22
# 1994                        27
# 1995                        67
# 1996                        49
# 1997                        46
# 1998                        92
# 1999                        46
# 2000                        83
# ...

# %%
canada.iloc[66,39] #row,column ->index denge row column dono ka
# Out:
# 126

# %%
#multiple columns
canada.iloc[40, 9:].plot(kind = 'area') #9 k aage se sb visualise kr paa rhe but kiska h bta nhi sktw
# Out:
# <Axes: >

# %%
#primary key jismei unique values hoti h

# %%
canada.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
canada.set_index('OdName', inplace= True)

# %%
canada.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Western Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='OdName', length=195)

# %%
canada.loc['Australia']
# Out:
# Type                       Immigrants
# Coverage                   Foreigners
# AREA                              909
# AreaName                      Oceania
# REG                               927
# RegName     Australia and New Zealand
# DEV                               901
# DevName             Developed regions
# 1980                              702
# 1981                              639
# 1982                              484
# 1983                              317
# 1984                              317
# 1985                              319
# 1986                              356
# 1987                              467
# 1988                              410
# 1989                              553
# 1990                              620
# 1991                              640
# 1992                              734
# 1993                              886
# 1994                              702
# 1995                              668
# 1996                              699
# ...

# %%
canada.loc['Cambodia']
# Out:
# Type                Immigrants
# Coverage            Foreigners
# AREA                       935
# AreaName                  Asia
# REG                        920
# RegName     South-Eastern Asia
# DEV                        902
# DevName     Developing regions
# 1980                        12
# 1981                        19
# 1982                        26
# 1983                        33
# 1984                        10
# 1985                         7
# 1986                         8
# 1987                        14
# 1988                        15
# 1989                        27
# 1990                        34
# 1991                        38
# 1992                        93
# 1993                       418
# 1994                       371
# 1995                       286
# 1996                       216
# 1997                       313
# 1998                       241
# 1999                       165
# 2000                       245
# 2001                       259
# ...

# %%
years = list(range(1980,2014))
print(years)
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
canada.loc['Japan',years].plot(kind='area',title='Japan Immigration to Canada',
    figsize=(15,5))
# Out:
# <Axes: title={'center': 'Japan Immigration to Canada'}>

# %%
countries = ['Cambodia','Japan','France']
canada.loc[countries,years]
# Out:
#           1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  \
# OdName
# Cambodia    12    19    26    33    10     7     8    14    15    27    34
# Japan      701   756   598   309   246   198   248   422   324   494   379
# France    1729  2027  2219  1490  1169  1177  1298  1658  2038  2332  2177
#
#           1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  \
# OdName
# Cambodia    38    93   418   371   286   216   313   241   165   245   259
# Japan      506   605   907   956   826   994   924   897  1083  1010  1092
# France    2911  3487  3709  2759  3332  2623  2473  3214  3343  3765  3806
#
#           2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# OdName
# Cambodia   230   277   348   370   529   460   354   203   200   196   233
# Japan      806   817   973  1067  1212  1250  1284  1194  1168  1265  1214
# France    3463  3568  4391  4429  4002  4290  4532  5051  4646  4080  6280
#
#           2013
# OdName
# ...

# %%
canada.loc[countries,years].T.plot(kind='line',title= f'{",".join(countries)}',figsize=(15,5))
plt.savefig('Compairing 3-countries.png')

# %%
countries = ['Cambodia','Japan','France','India']
canada.loc[countries,years]
# Out:
#           1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  \
# OdName
# Cambodia    12    19    26    33    10     7     8     14     15     27
# Japan      701   756   598   309   246   198   248    422    324    494
# France    1729  2027  2219  1490  1169  1177  1298   1658   2038   2332
# India     8880  8670  8147  7338  5704  4211  7150  10189  11522  10343
#
#            1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# OdName
# Cambodia     34     38     93    418    371    286    216    313    241
# Japan       379    506    605    907    956    826    994    924    897
# France     2177   2911   3487   3709   2759   3332   2623   2473   3214
# India     12041  13734  13673  21496  18620  18489  23859  22268  17241
#
#            1999   2000   2001   2002   2003   2004   2005   2006   2007  \
# OdName
# Cambodia    165    245    259    230    277    348    370    529    460
# ...

# %%
canada.loc[countries,years].T.plot(kind='area',title= f'{",".join(countries)}',figsize=(15,5))
plt.savefig('Compairing 4-countries.png')
